# %% [markdown]
#                                                        MODELOS DE CAPAS

# %% [markdown]
# $$\dfrac {\partial \overrightarrow {u}_{i}}{\partial t}+\overrightarrow {u}_{i}\cdot {\nabla  \overrightarrow u}_{i}+f  \overrightarrow {k}\times \overrightarrow {u}_{i}=-\dfrac {1}{\rho _{0}}\nabla P_{i}$$

# %% [markdown]
# $$\dfrac {\partial h_{i}}{\partial t}+\nabla \cdot \left( h\overrightarrow {u}_{i}\right) =0$$
#
# $$\dfrac {\partial P}{\partial z}=-\rho g$$

# %%
from IPython.display import Image

Image(filename='/Users/julios/python/notebooks/files/git_nb_files/capas.png', width=600)

# %%
Image(filename='/Users/julios/python/notebooks/files/git_nb_files/twolayer.png', width=600)

# %%
Image(filename='/Users/julios/python/notebooks/files/git_nb_files/modos-2-capas.png', width=600)

# %%
Image(filename='/Users/julios/python/notebooks/files/git_nb_files/twolayer-linear-eqs.png', width=600)

# %% [markdown]
# $$ \lambda = \dfrac{ g\mu+g'}{g\mu}$$
#
# $$ \dfrac {1}{\mu-1} = \dfrac {H_{2} \lambda} {H_{1}} $$

# %% [markdown]
# $$ H_{2} \lambda^{2} + ( H_{1} - H_{2} - \dfrac {g' H_{2}}{g}) \lambda  - H_{1}= 0 $$
#
# $$ \dfrac {g' H_{2}}{g} \approx 0 $$
#
# $$\lambda= \dfrac {(H_{2}-H_{1}) \pm (H_{1} + H_{2})} {2H_{2}}  $$

# %% [markdown]
# ## Ecuación de Energía

# %% [markdown]
# $$hu\partial _{t}u=h\partial _{t}\dfrac {u^{2}}{2}=\partial _{t}h\dfrac {u^{2}}{2}-\dfrac {u^{2}}{2}\partial _{t}h$$
# $$huu\partial _{x}u=hu\partial _{x}\dfrac {u^{2}}{2}=\partial _{x}\left( hu\dfrac {u^{2}}{2}\right) -\dfrac {u^{2}}{2}\partial _{x}(hu)$$
# $$huv\partial _{y}u=hv\partial _{y}\dfrac {u^{2}}{2}=\partial _{y}\left( hv\dfrac {u^{2}}{2}\right) -\dfrac {u^{2}}{2}\partial _{y}\left( hv\right) $$
# $$-fhuv=-ghu\partial _{x}\eta =-g\partial _{x}\left( hu\eta \right) +g\eta \partial _{x}hu$$
# $$\partial _{t}\left( \dfrac {h_{1}u^{2}_{1}}{2}\right) +\partial _{x}\left( u_{1}h_{1}\dfrac {u^{2}_{1}}{2}\right) +\partial _{y}\left( v_{1}\dfrac {h_{1}u^{2}_{1}}{2}\right) -fh_{1}u_{1}v_{1}=-g\partial _{x}\left( h_{1}u_{1}\eta \right) +g\eta \partial _{x}\left( h_{1}u_{1}\right) $$
# $$\partial _{t}\left( \dfrac {h_{1}v^{2}_{1}}{2}\right) +\partial _{x}\left( u_{1}h_{1}\dfrac {v^{2}_{1}}{2}\right) +\partial _{y}\left( v_{1}\dfrac {h_{1}v^{2}_{1}}{2}\right) +fh_{1}u_{1}v_{1}=-g\partial _{y}\left( h_{1}v_{1}\eta \right) +g\eta \partial _{y}\left( h_{1}v_{1}\right) $$
# $$g\eta \left[ \partial _{t}\left( \eta -a\right) +\partial _{x}\left( h_{1}u_{1}\right) +\partial _{y}\left( h_{1}v_{1}\right) \right] =0$$$\partial _{t}\dfrac {g\eta ^{2}}{2}=-g\eta \left( \partial _{x}\left( h_{1}u_{1}\right) +\partial _{y}\left( h_{1}v_{1}\right) \right) +g\eta \partial _{t}a$ i
#
# $$\partial _{t}\dfrac {g\eta ^{2}}{2}=-g\eta \left( \partial _{x}\left( h_{1}u_{1}\right) +\partial _{y}\left( h_{1}v_{1}\right) \right) -g\eta \left( \partial _{x}\left( h_{2}u_{2}\right) +\partial _{y}\left( h_{2}v_{2}\right) \right) $$
#
# $$\partial _{t}\left( h_{2}\dfrac {u^{2}_{2}+v^{2}_{2}}{2}\right) +\partial _{x}\left( u_{2}h_{2}\left( \dfrac {u^{2}_{2}+v^{2}_{2}}{2}\right) \right) +...=\left( g\eta +g'a\right) \left[ \partial _{x}\left( h_{2}u_{2}\right) +\partial _{y}\left( h_{2}v_{2}\right) \right] $$
#
# $$g'a\left( \partial _{t}a+\partial _{x}\left( h_{2}u_{2}\right) +\partial _{y}\left( h_{2}v_{2}\right) \right) =0$$
#
# $$\partial _{t}g'\dfrac {a^{2}}{2}=-a\left( \partial _{x}\left( h_{2}u_{2}\right) +\partial _{y}\left( h_{2}v_{2}\right) \right) $$

# %% [markdown]
# ## VORTICIDAD POTENCIAL

# %%
Image(filename='/Users/julios/python/notebooks/files/git_nb_files/potential-vorticity.png', width=600)

# %% [markdown]
# AJUSTE GEOSTRÓFICO DE UN FRENTE MODELO GRAVEDAD REDUCIDA
#
# $$\dfrac {f+v_{x-}u_{y}}{h}=\dfrac {f}{H}$$
#
# $$fv=g'\partial _{x}h$$
#
# $$\dfrac {f^{2}+g'\dfrac {d^{2}h}{dx^{2}}}{h}=\dfrac {f^{2}}{H}$$
#
# $$R^{2}\dfrac {d^{2}h}{dx^{2}}-h-H=0$$

# %%
# %pylab inline
from sympy import *

# %%
from __future__ import division
x, d = symbols('x,d')
R=symbols('R',positive=True)
H=symbols('H',positive=True)

# %%
integrate(exp(x/R),x)
# Out:
# R*exp(x/R)

# %%
f=Function('f')(x)

# %%
g=f.diff(x, x)-(R**2*f)-R**-2*H
dsolve(f.diff(x, x)- (R**-2*f)+R**-2*H, f)
# Out:
# f(x) == C1*exp(-x/R) + C2*exp(x/R) + H

# %%
d=var('d')
g=lambda x:C2*exp((x-d)/R) + H

# %%
plot(-100*(1-exp((x-10.0)/10.0)),(x,-100.0,10.0))
