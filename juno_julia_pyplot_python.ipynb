# %%
import matplotlib.pyplot as plt
#import datetime as dt
import numpy as np
from netCDF4 import Dataset
import warnings
warnings.filterwarnings('ignore')

# %%
file="/Users/julios/Downloads/ocnt15.gdas.200912.nc"
data=Dataset(file,'r');
pt=data.variables['pt'][:];
lon=data.variables['lon'][:];
lat=data.variables['lat'][:];
depth=data.variables['depth'][:];
time=data.variables['time'][:];

# %%
pc1=np.squeeze(pt[0,:,:,:]);
pc1[pc1 < -1.e33]=np.nan;

# %%
# %matplotlib inline 
plt.figure()
plt.contourf(lon,lat,pc1,273+np.arange(-1,30.5))
plt.show();

# %%
pt[pt < -1.e33]=np.nan;
plt.contourf(lon,lat,np.squeeze(pt[100,:,:,:]),273+np.arange(-1,30.5))
plt.show()

# %%
x=np.random.randn(5,4)
y=np.random.randn(5,4)

# %%
y.shape
# Out:
# (5, 4)

# %%
xy=
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-84d27a01b6f9> in <module>()
# ----> 1 xy=dot(x.T,y)
#
# NameError: name 'dot' is not defined

# %%
xy.shape
# Out:
# (5, 4)

# %%
xx.shape
# Out:
# (5,)
